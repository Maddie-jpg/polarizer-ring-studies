# %%
import sys
import os

# Adds the parent directory to the search path
parent_dir = os.path.abspath('..')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
import xtrack as xt
import numpy as np
import os
import matplotlib.pyplot  as plt
import matplotlib.patches as patches
import xpart as xp
import xobjects as xo
import math
import constants

# %%
# %% create environment, parameters and first simple cells & structures
n=7

pdr = xt.Environment()
pdr.particle_ref = xt.Particles(kinetic_energy0=2.86e9, mass0 = xt.ELECTRON_MASS_EV)

E0 = constants.E0; VRF = constants.VRF # beam energy in eV and RF voltage (1 cavity) in V

pdr.vars({'l_cell': 3.40,'l_bend': 0.40,'l_bendDS': 0.55,'dl_noben': 0.25, 'l_quad': 0.30,
  'l_drift': '(l_cell - 2*l_bend - 2*l_quad)/4.','dl_drift': -0.15, 'dl_trans': 0.00,
  'l_doub':  0.25, 'l_tripl': 3.0, 'l_trips': 0.40, 'l_sext': 0.10, })



pdr.vars({'N_cells_S': 8,'hBarc' : '6.283185307/(6*(2*N_cells_S*l_bend + l_bendDS))',
  'kQFarc': 2.9478, 'kQDarc':-2.9231,'kQFarcM': 2.8846, 'kQDarcM':-2.7567, 
  'kQFDS': 2.8042, 'kQDDS':-2.2858, 'kQFDoub': 3.9170, 'kQDDoub':-2.5190, 
  'kQFtr': 4.4429, 'kQDtr':-2.4723,  } )

U0 = (0.88463e-31)*E0**4*(2.*np.pi)/(6*(2*pdr['N_cells_S']*pdr['l_bend'] + pdr['l_bendDS']) )

pdr.new('Bend', xt.Bend, length='l_bend', angle='hBarc*l_bend', k0_from_h=True, 
         edge_entry_angle='hBarc*l_bend/2', edge_exit_angle='hBarc*l_bend/2')
pdr.new('QFarc',  xt.Quadrupole, length='l_quad',    k1='kQFarc' )
pdr.new('QFarcH', xt.Quadrupole, length='l_quad/2.', k1='kQFarc' )
pdr.new('Drarc',  xt.Drift,      length='l_drift' )
pdr.new('DrarcS', xt.Drift,      length='l_drift + dl_drift' )
pdr.new('QDarc',  xt.Quadrupole, length='l_quad',    k1='kQDarc' )
pdr.new('QFarcM', xt.Quadrupole, length='l_quad',    k1='kQFarcM' )
pdr.new('QDarcM', xt.Quadrupole, length='l_quad',    k1='kQDarcM' )
pdr.new('BendDS', xt.Bend, length='l_bendDS', angle='hBarc*l_bendDS', k0_from_h=True, 
         edge_entry_angle='hBarc*l_bendDS/2', edge_exit_angle='hBarc*l_bendDS/2')
pdr.new('QFDS',   xt.Quadrupole, length='l_quad',    k1='kQFDS' )
pdr.new('QDDS',   xt.Quadrupole, length='l_quad',    k1='kQDDS' )
pdr.new('DrDSL',  xt.Drift,      length='2*l_drift + l_bend + dl_noben' )
pdr.new('DrTrans',xt.Drift,      length='l_drift + dl_trans' )
pdr.new('QFDoub', xt.Quadrupole, length='l_quad',    k1='kQFDoub' )
pdr.new('QDDoub', xt.Quadrupole, length='l_quad',    k1='kQDDoub' )
pdr.new('DrDoub', xt.Drift,      length='l_doub' )

pdr.new('QFtr',    xt.Quadrupole, length='l_quad',    k1='kQFtr' )
pdr.new('QFtrH',   xt.Quadrupole, length='l_quad/2.', k1='kQFtr' )
pdr.new('QDtr',    xt.Quadrupole, length='l_quad',    k1='kQDtr' )
pdr.new('QDtrH',   xt.Quadrupole, length='l_quad',    k1='kQDtr' )
pdr.new('DrTripl', xt.Drift,      length='l_tripl' )
pdr.new('DrTrips', xt.Drift,      length='l_trips' )
# Out:
# 'DrTrips'

# %%
# just an arc cell
cell_arcS = pdr.new_line( length='l_cell', 
    components =[ 
    pdr.new('QF_cell_arc',    'QFarc',at='0*l_drift + 0.5*l_quad + 0.0*l_bend'),
    pdr.new('Bend1_cell_arc', 'Bend', at='1*l_drift + 1.0*l_quad + 0.5*l_bend'),
    pdr.new('QD_cell_arc',    'QDarc',at='2*l_drift + 1.5*l_quad + 1.0*l_bend'),
    pdr.new('Bend2_cell_arc', 'Bend', at='3*l_drift + 2.0*l_quad + 1.5*l_bend'),
    ])
cell_arcS.survey().plot()
print(cell_arcS.get_length())
cell_arc = pdr.new_line( components = [ 
   pdr.new('QF_cell_arcH1',  'QFarcH' ), pdr.place( 'Drarc' ),
   pdr.new('Bend1_cell_arcH','Bend' ),   pdr.place( 'Drarc' ),
   pdr.new('QD_cell_arcH',   'QDarc' ),  pdr.place( 'Drarc' ),
   pdr.new('Bend2_cell_arcH','Bend' ),   pdr.place( 'Drarc' ),
   pdr.new('QF_cell_arcH2',  'QFarcH' ), 
   ])
cell_arc.survey().plot()
print(cell_arc.get_length())
# triplet starting with 
cell_tr = pdr.new_line(
    components = [
    pdr.new('QF_cell_trH1', 'QFtrH',    at='0*l_trips + 0.25*l_quad + 0.0*l_tripl'),
    pdr.new('QD_cell_tr1',  'QDtr',     at='1*l_trips + 1.00*l_quad + 0.0*l_tripl'),
    pdr.new('Mkr_cell_tr',   xt.Marker, at='1*l_trips + 1.50*l_quad + 0.5*l_tripl'),
    pdr.new('QD_cell_tr2',  'QDtr',     at='1*l_trips + 2.00*l_quad + 1.0*l_tripl'),
    pdr.new('QF_cell_trH2', 'QFtrH',    at='2*l_trips + 2.75*l_quad + 1.0*l_tripl')
    ])

print(cell_tr.get_length())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xplt/hooks.py:31: RuntimeWarning: Failed to register formatters with pint: No module named 'pint'
#   warnings.warn(f"Failed to register formatters with pint: {e}", RuntimeWarning)
# 3.4
# 3.3999999999999995
# 4.7

# %%
def makesextant ( name, fall ):
    comps = [ ]
    for ind in range( pdr['N_cells_S'] - 1 ):  # regular arc cells
       comps = comps + [ pdr.place('Drarc'), pdr.new('Bend1_' + name + str(ind+1), 'Bend')]
       comps = comps + [ pdr.place('Drarc'), pdr.new('QDA_' + name + str(ind+1), 'QDarc')]
       comps = comps + [ pdr.place('Drarc'), pdr.new('Bend2_' + name + str(ind+1), 'Bend')]
       comps = comps + [ pdr.place('Drarc'), pdr.new('QFA_' + name + str(ind+1), 'QFarc')]

    # Replace last QF and add last arc cell (matching quads) "by hand"

    comps[-1] = pdr.new('QFA_M' + name + str(pdr['N_cells_S']-1), 'QFarcM' )
    comps = comps + [pdr.place('DrarcS'),pdr.new('Bend1_' + name + str(pdr['N_cells_S']), 'Bend')]
    comps = comps + [pdr.place('Drarc'), pdr.new('QDA_M' + name + str(pdr['N_cells_S']), 'QDarcM')]
    comps = comps + [pdr.place('Drarc'), pdr.new('Bend2_' + name + str(pdr['N_cells_S']), 'Bend')]

    # Add dispersion suppressor
    comps = comps + [pdr.place('Drarc'), pdr.new('QFDS_' + name, 'QFDS') ]
    comps = comps + [pdr.place('DrDSL'), pdr.new('QDDS_' + name, 'QDDS') ]
    comps = comps + [pdr.place('Drarc'), pdr.new('BendDS_' + name, 'BendDS')]

    # Add doublet matching 
    comps = comps + [pdr.place('DrTrans'), pdr.new('QFDoub_' + name, 'QFDoub')]
    comps = comps + [pdr.place('DrDoub'), pdr.new('QDDoub_' + name, 'QDDoub')]   
    comps = comps + [pdr.place('DrTripl'), pdr.new('QDTrip_' + name + '1', 'QDtr')]  

    if fall == 'symm':
       comps = [ pdr.new('QFA_' + name + 'CH', 'QFarcH' ) ] + comps
       comps = comps + [ pdr.place('DrTrips'), pdr.new('QFTripC_' + name + '2H', 'QFtrH')]

    elif fall == 'right':
       comps = [ pdr.new('QFA_' + name + 'C', 'QFarc'  ) ] + comps + [ pdr.place('DrTrips') ]
    elif fall == 'left':
       comps = comps + [pdr.place('DrTrips'), pdr.new('QFTripC_' + name + '2', 'QFtr') ]
       comps = list( reversed(comps) )

    else:
       print( '=====> choice for sextant version incorrect <=====' )
       quit()

    return pdr.new_line( components = comps )

# %%
arc1R = makesextant( 'xR', 'symm' )
arc1R_sliced = arc1R.select()
arc1R_sliced.cut_at_s( np.linspace(.05, arc1R.get_length()-.05, int(arc1R.get_length()/.05-.5)) )
arc1R.insert( pdr.new('CtrS1_xR1', xt.Marker ), at='(l_tripl+l_quad)/2', from_='QDDoub_xR' )
# Out:
# Slicing line:   0%|          | 0/77 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/77 [00:00<?, ?it/s]

# %%
# One period from center of arc to center of arc
period = makesextant( 'PR', 'symm') + ( -makesextant( 'PL', 'symm') )
period_sliced = period.select()
period_sliced.cut_at_s( np.linspace(.05, period.get_length()-.05, int(period.get_length()/.05-.5)) )
# Out:
# Slicing line:   0%|          | 0/154 [00:00<?, ?it/s]

# %%
# Full ring without X-poles, RF and wigglers
ring  = makesextant( '1R', 'right') + makesextant( '2L', 'left') + makesextant( '2R', 'right') + makesextant( '3L', 'left') + makesextant( '3R', 'right') + makesextant( '1L', 'left')
fRev = 1./(ring.twiss(method='4d').T_rev0)
fRF  = fRev*round(4.e8/fRev)  # at integer harmonics and close to 400 MHz
pdr.new('RFCav',  xt.Cavity, length=1.5, frequency=fRF, voltage=VRF, 
        lag=(180/np.pi)*(np.pi - np.arcsin(U0/VRF)) - 1.8 ) 
ring.insert( pdr.new('RFCav_1', 'RFCav'), at='(l_tripl+l_quad)/2', from_='QDDoub_1R' )
ring.configure_radiation(model='mean')
ring.configure_bend_model(edge='full')
# Out:
# Slicing line:   0%|          | 0/456 [00:00<?, ?it/s]

# %%
# %% Routine for several matchings in a row for 90 degrees arc cells and given tunes

# Matching of arc cell
cell_arc_opt = cell_arc.match( method='4d', solve=True, verbose=False,
    vary=[
        xt.VaryList(['kQFarc', 'kQDarc', 'kQFarcM'], step=1e-4),    ],
    targets=[
        xt.TargetSet(qx=0.25, qy=0.25, tol=1.0e-6, tag='end'), # just twice the same 
        xt.TargetSet(mux=0.25, muy=0.25, at=xt.END, tol=1.0e-6)]  )

# Triplet cell to chosen betatron functions
cell_tr_opt = cell_tr.match( method='4d', solve=True,
    vary=[ # use individual Vary commands instead of List for arc cell
        xt.Vary('kQFtr', step=1e-4 ),
        xt.Vary('kQDtr', step=1e-4),    ],
    targets=[
        xt.TargetSet(betx=2.50, bety=2.50, at='Mkr_cell_tr', tol=1.0e-6, tag='betas')] )

def matchingWP( qx, qy, MakePlot=False ):
    cell_arc_opt.run_jacobian(10)
    cell_arc_tw = cell_arc.twiss( method='4d' )
    arc1R_opttune = arc1R.match( method='4d', solve=True, verbose=False,
                 betx=cell_arc_tw.betx[0], alfx=cell_arc_tw.alfx[0],
                 bety=cell_arc_tw.bety[0], alfy=cell_arc_tw.alfy[0],
                 dx=cell_arc_tw.dx[0],     dpx=cell_arc_tw.dpx[0],
            vary=[ xt.VaryList(['kQFarcM', 'kQDarcM'], step=1e-4),
                   xt.VaryList(['kQFDS', 'kQDDS'], step=1e-4),
                   xt.VaryList(['kQFDoub', 'kQDDoub'], step=1e-4),
                   xt.VaryList(['kQFtr', 'kQDtr'], step=1e-4), ],
            targets=[ xt.TargetSet(dx=0, dpx=0, at=xt.END, tol=1.0e-9),
                      xt.TargetSet(mux=qx/6, muy=qy/6, at=xt.END, 
                                   tol=1.0e-9, weight=.1, tag='phase'),
                      xt.TargetSet(alfx=0, alfy=0, at=xt.END, tol=1.0e-9),
                      xt.TargetSet(alfx=0, alfy=0, at='CtrS1_xR1', 
                                   tol=1.0e-9, weight=10.) ])
    arc1R_opttune.run_jacobian(50)
    if MakePlot:
       arc1R.twiss( method='4d',
                    betx=cell_arc_tw.betx[0], alfx=cell_arc_tw.alfx[0],
                    bety=cell_arc_tw.bety[0], alfy=cell_arc_tw.alfy[0],
                    dx=cell_arc_tw.dx[0],     dpx=cell_arc_tw.dpx[0],).plot()

        
# Matching sequence for sextant with beta at center of straights fixed
def matchingBeta( betxS, betyS, MakePlot=False ): #, **kwargs ):
    cell_arc_opt.run_jacobian(10)
    cell_arc_tw = cell_arc.twiss( method='4d' )
    cell_tr_opt.targets[0].value, cell_tr_opt.targets[1].value = betxS, betyS
    cell_tr_opt.run_jacobian(10)
    cell_tr_tw = cell_tr.twiss( method='4d' )
    arc1R_opt = arc1R.match( method='4d', solve=True,
                 betx=cell_arc_tw.betx[0], alfx=cell_arc_tw.alfx[0],
                 bety=cell_arc_tw.bety[0], alfy=cell_arc_tw.alfy[0],
                 dx=cell_arc_tw.dx[0],     dpx=cell_arc_tw.dpx[0],
            vary=[ xt.VaryList(['kQFarcM', 'kQDarcM'], step=1e-4),
                   xt.VaryList(['kQFDS', 'kQDDS'], step=1e-4),
                   xt.VaryList(['kQFDoub', 'kQDDoub'], step=1e-4) ],
            targets=[ xt.TargetSet(dx=0, dpx=0, at=xt.END, tol=1.0e-9),
                      xt.TargetSet(alfx=0, alfy=0, at=xt.END, tol=1.0e-9),
                      xt.TargetSet(betx=cell_tr_tw.betx[0], bety=cell_tr_tw.bety[0],
                                   at=xt.END, tol=1.0e-9) ])
    arc1R_opt.run_jacobian(10)
    if MakePlot:
       arc1R.twiss( method='4d',
                    betx=cell_arc_tw.betx[0], alfx=cell_arc_tw.alfx[0],
                    bety=cell_arc_tw.bety[0], alfy=cell_arc_tw.alfy[0],
                    dx=cell_arc_tw.dx[0],     dpx=cell_arc_tw.dpx[0],).plot() 
       

matchingWP(*constants.WP)

cell_tr_tw = cell_tr.twiss(method='4d')
mid_idx = len(cell_tr_tw.betx) // 2
betxS = cell_tr_tw.betx[mid_idx]
betyS = cell_tr_tw.bety[mid_idx]
matchingBeta( betxS, betyS, MakePlot=False )
# Out:
# Matching: model call n. 1 penalty = 8.5606e-05
# Matching: model call n. 2 penalty = 8.5606e-05
# Matching: model call n. 3 penalty = 2.7348e-04
# Matching: model call n. 4 penalty = 2.1535e-04
# Matching: model call n. 5 penalty = 8.5606e-05
# Matching: model call n. 6 penalty = 8.5606e-05
# Matching: model call n. 7 penalty = 2.6271e-10
#
# Matching: model call n. 1 penalty = 8.8384e-01
# Optimize - start penalty: 0.8838
# Matching: model call n. 2 penalty = 8.8384e-01
# Matching: model call n. 3 penalty = 8.8408e-01
# Matching: model call n. 4 penalty = 8.8409e-01
# Matching: model call n. 5 penalty = 8.8384e-01
# Matching: model call n. 6 penalty = 2.1397e-01
# Matching: model call n. 7 penalty = 2.1397e-01
# Matching: model call n. 8 penalty = 2.1359e-01
# Matching: model call n. 9 penalty = 2.1365e-01
# Matching: model call n. 10 penalty = 2.1397e-01
# Matching: model call n. 11 penalty = 9.8984e-03
# Matching: model call n. 12 penalty = 9.8984e-03
# Matching: model call n. 13 penalty = 9.5526e-03
# Matching: model call n. 14 penalty = 9.6087e-03
# Matching: model call n. 15 penalty = 9.8984e-03
# Matching: model call n. 16 penalty = 2.2666e-05
# Matching: model call n. 17 penalty = 2.2666e-05
# Matching: model call n. 18 penalty = 3.2719e-04
# Matching: model call n. 19 penalty = 3.3695e-04
# Matching: model call n. 20 penalty = 2.2666e-05
# Matching: model call n. 21 penalty = 2.0237e-09
# Optimize - end penalty:  2.02373e-09
# Matching: model call n. 8 penalty = 2.6271e-10
# Matching: model call n. 9 penalty = 2.6271e-10
# Matching: model call n. 1 penalty = 4.2685e+00
# Matching: model call n. 2 penalty = 4.2685e+00
# Matching: model call n. 3 penalty = 4.2703e+00
# Matching: model call n. 4 penalty = 4.2685e+00
# Matching: model call n. 5 penalty = 4.2673e+00
# Matching: model call n. 6 penalty = 4.2688e+00
# Matching: model call n. 7 penalty = 4.2711e+00
# Matching: model call n. 8 penalty = 4.2699e+00
# Matching: model call n. 9 penalty = 4.2672e+00
# Matching: model call n. 10 penalty = 4.2672e+00
# Matching: model call n. 11 penalty = 4.2685e+00
# Matching: model call n. 12 penalty = 3.5854e+01
# Matching: model call n. 13 penalty = 7.8866e+00
# Matching: model call n. 14 penalty = 2.5419e+00
# Matching: model call n. 15 penalty = 2.5419e+00
# Matching: model call n. 16 penalty = 2.5433e+00
# Matching: model call n. 17 penalty = 2.5419e+00
# Matching: model call n. 18 penalty = 2.5408e+00
# Matching: model call n. 19 penalty = 2.5397e+00
# Matching: model call n. 20 penalty = 2.5436e+00
# Matching: model call n. 21 penalty = 2.5430e+00
# Matching: model call n. 22 penalty = 2.5406e+00
# Matching: model call n. 23 penalty = 2.5407e+00
# Matching: model call n. 24 penalty = 2.5419e+00
# Matching: model call n. 25 penalty = 1.7815e+03
# Matching: model call n. 26 penalty = 3.7040e+01
# Matching: model call n. 27 penalty = 8.0292e+00
# Matching: model call n. 28 penalty = 2.8153e+00
# Matching: model call n. 29 penalty = 2.4312e+00
# Matching: model call n. 30 penalty = 2.4312e+00
# Matching: model call n. 31 penalty = 2.4325e+00
# Matching: model call n. 32 penalty = 2.4312e+00
# Matching: model call n. 33 penalty = 2.4301e+00
# Matching: model call n. 34 penalty = 2.4276e+00
# Matching: model call n. 35 penalty = 2.4325e+00
# Matching: model call n. 36 penalty = 2.4319e+00
# Matching: model call n. 37 penalty = 2.4299e+00
# Matching: model call n. 38 penalty = 2.4300e+00
# Matching: model call n. 39 penalty = 2.4312e+00
# Matching: model call n. 40 penalty = 2.7168e+04
# Matching: model call n. 41 penalty = 1.3156e+02
# Matching: model call n. 42 penalty = 3.5089e+01
# Matching: model call n. 43 penalty = 7.2695e+00
# Matching: model call n. 44 penalty = 3.1502e+00
# Matching: model call n. 45 penalty = 3.1502e+00
# Matching: model call n. 46 penalty = 3.1512e+00
# Matching: model call n. 47 penalty = 3.1502e+00
# Matching: model call n. 48 penalty = 3.1490e+00
# Matching: model call n. 49 penalty = 3.1441e+00
# Matching: model call n. 50 penalty = 3.1504e+00
# Matching: model call n. 51 penalty = 3.1498e+00
# Matching: model call n. 52 penalty = 3.1491e+00
# Matching: model call n. 53 penalty = 3.1489e+00
# Matching: model call n. 54 penalty = 3.1502e+00
# Matching: model call n. 55 penalty = 1.3503e+08
# Matching: model call n. 56 penalty = 1.5736e+05
# Matching: model call n. 57 penalty = 1.4313e+02
# Matching: model call n. 58 penalty = 6.9076e+01
# Matching: model call n. 59 penalty = 1.6812e+01
# Matching: model call n. 60 penalty = 1.6812e+01
# Matching: model call n. 61 penalty = 1.6813e+01
# Matching: model call n. 62 penalty = 1.6812e+01
# Matching: model call n. 63 penalty = 1.6812e+01
# Matching: model call n. 64 penalty = 1.6818e+01
# Matching: model call n. 65 penalty = 1.6814e+01
# Matching: model call n. 66 penalty = 1.6815e+01
# Matching: model call n. 67 penalty = 1.6811e+01
# Matching: model call n. 68 penalty = 1.6812e+01
# Matching: model call n. 69 penalty = 1.6812e+01
# Matching: model call n. 70 penalty = 2.1181e+03
# Matching: model call n. 71 penalty = 2.6062e+02
# Matching: model call n. 72 penalty = 3.5946e+01
# Matching: model call n. 73 penalty = 4.7849e+00
# Matching: model call n. 74 penalty = 4.7849e+00
# Matching: model call n. 75 penalty = 4.7856e+00
# Matching: model call n. 76 penalty = 4.7862e+00
# Matching: model call n. 77 penalty = 4.7847e+00
# Matching: model call n. 78 penalty = 4.7884e+00
# Matching: model call n. 79 penalty = 4.7871e+00
# Matching: model call n. 80 penalty = 4.7883e+00
# Matching: model call n. 81 penalty = 4.7845e+00
# Matching: model call n. 82 penalty = 4.7865e+00
# Matching: model call n. 83 penalty = 4.7849e+00
# Matching: model call n. 84 penalty = 3.6913e+01
# Matching: model call n. 85 penalty = 9.3319e+00
# Matching: model call n. 86 penalty = 1.8809e+00
# Matching: model call n. 87 penalty = 1.8809e+00
# Matching: model call n. 88 penalty = 1.8818e+00
# Matching: model call n. 89 penalty = 1.8824e+00
# Matching: model call n. 90 penalty = 1.8804e+00
# Matching: model call n. 91 penalty = 1.8905e+00
# Matching: model call n. 92 penalty = 1.8847e+00
# Matching: model call n. 93 penalty = 1.8856e+00
# Matching: model call n. 94 penalty = 1.8796e+00
# Matching: model call n. 95 penalty = 1.8829e+00
# Matching: model call n. 96 penalty = 1.8809e+00
# Matching: model call n. 97 penalty = 5.4081e+03
# Matching: model call n. 98 penalty = 7.2735e+01
# Matching: model call n. 99 penalty = 4.5246e+00
# Matching: model call n. 100 penalty = 2.7163e+00
# Matching: model call n. 101 penalty = 2.1829e+00
# Matching: model call n. 102 penalty = 2.1829e+00
# Matching: model call n. 103 penalty = 2.1837e+00
# Matching: model call n. 104 penalty = 2.1845e+00
# Matching: model call n. 105 penalty = 2.1829e+00
# Matching: model call n. 106 penalty = 2.2032e+00
# Matching: model call n. 107 penalty = 2.1888e+00
# Matching: model call n. 108 penalty = 2.1898e+00
# Matching: model call n. 109 penalty = 2.1818e+00
# Matching: model call n. 110 penalty = 2.1860e+00
# Matching: model call n. 111 penalty = 2.1829e+00
# Matching: model call n. 112 penalty = 7.7685e+04
# Matching: model call n. 113 penalty = 1.2259e+02
# Matching: model call n. 114 penalty = 3.2560e+01
# Matching: model call n. 115 penalty = 1.7377e+00
# Matching: model call n. 116 penalty = 1.7377e+00
# Matching: model call n. 117 penalty = 1.7378e+00
# Matching: model call n. 118 penalty = 1.7372e+00
# Matching: model call n. 119 penalty = 1.7360e+00
# Matching: model call n. 120 penalty = 1.7142e+00
# Matching: model call n. 121 penalty = 1.7337e+00
# Matching: model call n. 122 penalty = 1.7338e+00
# Matching: model call n. 123 penalty = 1.7360e+00
# Matching: model call n. 124 penalty = 1.7361e+00
# Matching: model call n. 125 penalty = 1.7377e+00
# Matching: model call n. 126 penalty = 5.1005e+15
# Matching: model call n. 127 penalty = 5.6832e+14
# Matching: model call n. 128 penalty = 3.4214e+11
# Matching: model call n. 129 penalty = 9.9415e+08
# Matching: model call n. 130 penalty = 1.1551e+06
# Matching: model call n. 131 penalty = 2.3023e+03
# Matching: model call n. 132 penalty = 4.4172e+01
# Matching: model call n. 133 penalty = 1.6368e+01
# Matching: model call n. 134 penalty = 1.6368e+01
# Matching: model call n. 135 penalty = 1.6369e+01
# Matching: model call n. 136 penalty = 1.6370e+01
# Matching: model call n. 137 penalty = 1.6368e+01
# Matching: model call n. 138 penalty = 1.6374e+01
# Matching: model call n. 139 penalty = 1.6370e+01
# Matching: model call n. 140 penalty = 1.6371e+01
# Matching: model call n. 141 penalty = 1.6368e+01
# Matching: model call n. 142 penalty = 1.6370e+01
# Matching: model call n. 143 penalty = 1.6368e+01
# Matching: model call n. 144 penalty = 4.0339e+11
# Matching: model call n. 145 penalty = 2.1957e+08
# Matching: model call n. 146 penalty = 1.7061e+05
# Matching: model call n. 147 penalty = 3.8656e+02
# Matching: model call n. 148 penalty = 1.6890e+01
# Matching: model call n. 149 penalty = 1.6890e+01
# Matching: model call n. 150 penalty = 1.6889e+01
# Matching: model call n. 151 penalty = 1.6887e+01
# Matching: model call n. 152 penalty = 1.6889e+01
# Matching: model call n. 153 penalty = 1.6852e+01
# Matching: model call n. 154 penalty = 1.6883e+01
# Matching: model call n. 155 penalty = 1.6885e+01
# Matching: model call n. 156 penalty = 1.6889e+01
# Matching: model call n. 157 penalty = 1.6888e+01
# Matching: model call n. 158 penalty = 1.6890e+01
# Matching: model call n. 159 penalty = 1.7396e+01
# Matching: model call n. 160 penalty = 1.2926e+01
# Matching: model call n. 161 penalty = 1.2926e+01
# Matching: model call n. 162 penalty = 1.2926e+01
# Matching: model call n. 163 penalty = 1.2924e+01
# Matching: model call n. 164 penalty = 1.2926e+01
# Matching: model call n. 165 penalty = 1.2888e+01
# Matching: model call n. 166 penalty = 1.2918e+01
# Matching: model call n. 167 penalty = 1.2921e+01
# Matching: model call n. 168 penalty = 1.2926e+01
# Matching: model call n. 169 penalty = 1.2924e+01
# Matching: model call n. 170 penalty = 1.2926e+01
# Matching: model call n. 171 penalty = 1.7098e+01
# Matching: model call n. 172 penalty = 1.3192e+01
# Matching: model call n. 173 penalty = 1.1765e+01
# Matching: model call n. 174 penalty = 1.1765e+01
# Matching: model call n. 175 penalty = 1.1765e+01
# Matching: model call n. 176 penalty = 1.1763e+01
# Matching: model call n. 177 penalty = 1.1765e+01
# Matching: model call n. 178 penalty = 1.1734e+01
# Matching: model call n. 179 penalty = 1.1759e+01
# Matching: model call n. 180 penalty = 1.1761e+01
# Matching: model call n. 181 penalty = 1.1765e+01
# Matching: model call n. 182 penalty = 1.1763e+01
# Matching: model call n. 183 penalty = 1.1765e+01
# Matching: model call n. 184 penalty = 1.0317e+01
# Matching: model call n. 185 penalty = 1.0317e+01
# Matching: model call n. 186 penalty = 1.0318e+01
# Matching: model call n. 187 penalty = 1.0316e+01
# Matching: model call n. 188 penalty = 1.0316e+01
# Matching: model call n. 189 penalty = 1.0316e+01
# Matching: model call n. 190 penalty = 1.0318e+01
# Matching: model call n. 191 penalty = 1.0317e+01
# Matching: model call n. 192 penalty = 1.0315e+01
# Matching: model call n. 193 penalty = 1.0315e+01
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xtrack/particles/particles.py:1770: RuntimeWarning: invalid value encountered in sqrt
#   out = sqrt((1 + self.delta) ** 2 - self.kin_px ** 2 - self.kin_py ** 2)
# Matching: model call n. 194 penalty = 1.0317e+01
# Matching: model call n. 195 penalty = 1.2830e+01
# Matching: model call n. 196 penalty = 5.5304e+00
# Matching: model call n. 197 penalty = 5.5304e+00
# Matching: model call n. 198 penalty = 5.5319e+00
# Matching: model call n. 199 penalty = 5.5300e+00
# Matching: model call n. 200 penalty = 5.5293e+00
# Matching: model call n. 201 penalty = 5.5311e+00
# Matching: model call n. 202 penalty = 5.5325e+00
# Matching: model call n. 203 penalty = 5.5312e+00
# Matching: model call n. 204 penalty = 5.5277e+00
# Matching: model call n. 205 penalty = 5.5290e+00
# Matching: model call n. 206 penalty = 5.5304e+00
# Matching: model call n. 207 penalty = 2.8532e+00
# Matching: model call n. 208 penalty = 2.8532e+00
# Matching: model call n. 209 penalty = 2.8534e+00
# Matching: model call n. 210 penalty = 2.8549e+00
# Matching: model call n. 211 penalty = 2.8529e+00
# Matching: model call n. 212 penalty = 2.8505e+00
# Matching: model call n. 213 penalty = 2.8529e+00
# Matching: model call n. 214 penalty = 2.8530e+00
# Matching: model call n. 215 penalty = 2.8530e+00
# Matching: model call n. 216 penalty = 2.8536e+00
# Matching: model call n. 217 penalty = 2.8532e+00
# Matching: model call n. 218 penalty = 1.6328e+00
# Matching: model call n. 219 penalty = 1.6328e+00
# Matching: model call n. 220 penalty = 1.6331e+00
# Matching: model call n. 221 penalty = 1.6347e+00
# Matching: model call n. 222 penalty = 1.6326e+00
# Matching: model call n. 223 penalty = 1.6298e+00
# Matching: model call n. 224 penalty = 1.6331e+00
# Matching: model call n. 225 penalty = 1.6334e+00
# Matching: model call n. 226 penalty = 1.6323e+00
# Matching: model call n. 227 penalty = 1.6332e+00
# Matching: model call n. 228 penalty = 1.6328e+00
# Matching: model call n. 229 penalty = 4.3763e-02
# Matching: model call n. 230 penalty = 4.3763e-02
# Matching: model call n. 231 penalty = 4.4013e-02
# Matching: model call n. 232 penalty = 4.4013e-02
# Matching: model call n. 233 penalty = 4.3527e-02
# Matching: model call n. 234 penalty = 4.3933e-02
# Matching: model call n. 235 penalty = 4.4064e-02
# Matching: model call n. 236 penalty = 4.4105e-02
# Matching: model call n. 237 penalty = 4.3782e-02
# Matching: model call n. 238 penalty = 4.3287e-02
# Matching: model call n. 239 penalty = 4.3763e-02
# Matching: model call n. 240 penalty = 1.4977e-04
# Matching: model call n. 241 penalty = 1.4977e-04
# Matching: model call n. 242 penalty = 1.7645e-03
# Matching: model call n. 243 penalty = 2.1547e-03
# Matching: model call n. 244 penalty = 1.7928e-03
# Matching: model call n. 245 penalty = 2.9053e-03
# Matching: model call n. 246 penalty = 2.1522e-03
# Matching: model call n. 247 penalty = 1.1945e-03
# Matching: model call n. 248 penalty = 2.4858e-03
# Matching: model call n. 249 penalty = 1.4973e-03
# Matching: model call n. 250 penalty = 1.4977e-04
# Matching: model call n. 251 penalty = 1.5821e-08
# Matching: model call n. 252 penalty = 1.5821e-08
# Matching: model call n. 253 penalty = 1.8042e-03
# Matching: model call n. 254 penalty = 2.0342e-03
# Matching: model call n. 255 penalty = 1.7616e-03
# Matching: model call n. 256 penalty = 3.0366e-03
# Matching: model call n. 257 penalty = 2.2128e-03
# Matching: model call n. 258 penalty = 1.1995e-03
# Matching: model call n. 259 penalty = 2.4262e-03
# Matching: model call n. 260 penalty = 1.3779e-03
# Matching: model call n. 261 penalty = 1.5821e-08
# Matching: model call n. 262 penalty = 1.1331e-09
# Matching: model call n. 263 penalty = 1.1331e-09
# Matching: model call n. 264 penalty = 1.1331e-09
# Matching: model call n. 10 penalty = 2.6271e-10
# Matching: model call n. 11 penalty = 2.6271e-10
# Matching: model call n. 22 penalty = 0.0000e+00
# Optimize - start penalty: 0
# Matching: model call n. 23 penalty = 0.0000e+00
# Optimize - end penalty:     0
#
# Matching: model call n. 1 penalty = 1.7040e-09
# Optimize - start penalty: 1.704e-09
# Matching: model call n. 2 penalty = 1.7040e-09
# Matching: model call n. 3 penalty = 2.0531e-03
# Matching: model call n. 4 penalty = 1.4986e-03
# Matching: model call n. 5 penalty = 2.5056e-03
# Matching: model call n. 6 penalty = 2.4143e-03
# Matching: model call n. 7 penalty = 2.2751e-03
# Matching: model call n. 8 penalty = 1.0847e-03
# Matching: model call n. 9 penalty = 1.7040e-09
# Matching: model call n. 10 penalty = 1.0118e-09
# Optimize - end penalty:  1.01181e-09
#
# Matching: model call n. 11 penalty = 1.0118e-09
# Optimize - start penalty: 1.012e-09
# Matching: model call n. 12 penalty = 1.0118e-09
# Optimize - end penalty:  1.01181e-09

# %%
pdr.vars( { 'k2XF2arc': 0.00, 'k2XD2arc': 0.00, } )  # Sextupoles - two families defined here
pdr.new('XF2arc',  xt.Sextupole, length='l_sext',    k2='k2XF2arc' )
pdr.new('XD2arc',  xt.Sextupole, length='l_sext',    k2='k2XD2arc' )

pdr.vars( { 'k2XF2arc2': 0.00, 'k2XD2arc2': 0.00, } )  # Sextupoles - two families defined here
pdr.new('XF2arc2',  xt.Sextupole, length='l_sext',    k2='k2XF2arc2' )
pdr.new('XD2arc2',  xt.Sextupole, length='l_sext',    k2='k2XD2arc2' )

ringS2 = ring.select()   # should make a copy?
for elem in ([ [el, '-'] for el in ['1R1', '1R5', '2R1', '2R5', '3R1', '3R5'] ] +
             [ [el, '+'] for el in ['1L1', '1L5', '2L1', '2L5', '3L1', '3L5'] ]):
  ringS2.insert( pdr.new('XD2arc_'+elem[0], 'XD2arc'), 
                at=elem[1] + '(l_drift+l_quad)/2', from_='QDA_' + elem[0] )

for elem in ([ [el, '-'] for el in ['1R3', '1R7', '2R3', '2R7', '3R3', '3R7'] ] +
             [ [el, '+'] for el in ['1L3', '1L7', '2L3', '2L7', '3L3', '3L7'] ]):
  ringS2.insert( pdr.new('XD2arc_'+elem[0], 'XD2arc'), 
                at=elem[1] + '(l_drift+l_quad)/2', from_='QDA_' + elem[0] )

for elem in ([ [el, '-'] for el in ['1R3', '2R3', '3R3'] ] +
             [ [el, '+'] for el in ['1L3', '2L3', '3L3'] ]):

  ringS2.insert( pdr.new('XF2arc_'+elem[0], 'XF2arc'), 
                at=elem[1] + '(l_drift+l_quad)/2', from_='QFA_' + elem[0] )
  
for elem in ([ [el, '-'] for el in ['1R7', '2R7', '3R7'] ] +
             [ [el, '+'] for el in ['1L7', '2L7', '3L7'] ]):

  ringS2.insert( pdr.new('XF2arc_M'+elem[0], 'XF2arc'), 
                at=elem[1] + '(l_drift+l_quad)/2', from_='QFA_M' + elem[0] )
  
for elem in ([ [el, '-'] for el in ['1R1', '1R5', '2R1', '2R5', '3R1', '3R5'] ] +
             [ [el, '+'] for el in ['1L1', '1L5', '2L1', '2L5', '3L1', '3L5'] ]):
  ringS2.insert( pdr.new('XF2arc_'+elem[0], 'XF2arc'), 
                at=elem[1] + '(l_drift+l_quad)/2', from_='QFA_' + elem[0] )

ringS2.survey().plot()

periodS2 = period.select()
for elem in [ ['PR1', '-'], ['PR5', '-'], ['PL1', '+'], ['PL5', '+'] ]:
  periodS2.insert( pdr.new('XD2arc_'+elem[0], 'XD2arc'), 
                at=elem[1] + '(l_drift+l_quad)/2', from_='QDA_' + elem[0] )
for elem in [ ['PR3', '-'], ['PR7', '-'], ['PL3', '+'], ['PL7', '+'] ]:
  periodS2.insert( pdr.new('XD2arc_'+elem[0], 'XD2arc'), 
                at=elem[1] + '(l_drift+l_quad)/2', from_='QDA_' + elem[0] )
for elem in [ ['PR3', '-'],['PL3', '+'] ]:
  periodS2.insert( pdr.new('XF2arc_'+elem[0], 'XF2arc'), 
             at=elem[1] + '(l_drift+l_quad)/2', from_='QFA_' + elem[0] )
for elem in [ ['PR7', '-'],['PL7', '+'] ]:
  periodS2.insert( pdr.new('XF2arc_'+elem[0], 'XF2arc'), 
             at=elem[1] + '(l_drift+l_quad)/2', from_='QFA_M' + elem[0] )
for elem in [ ['PR1', '-'], ['PR5', '-'], ['PL1', '+'], ['PL5', '+'] ]:
  periodS2.insert( pdr.new('XF2arc_'+elem[0], 'XF2arc'), 
                at=elem[1] + '(l_drift+l_quad)/2', from_='QFA_' + elem[0] )

periodS2.survey().plot()

#  Just generate some output

periodS2_sliced = periodS2.select()
periodS2_sliced.cut_at_s( np.linspace(.05, period.get_length()-.05, int(period.get_length()/.05-.5)) )
# Out:
# Slicing line:   0%|          | 0/458 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/460 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/462 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/464 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/466 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/468 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/470 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/472 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/474 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/476 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/478 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/480 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/482 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/484 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/486 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/488 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/490 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/492 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/494 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/496 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/498 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/500 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/502 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/504 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/506 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/508 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/510 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/512 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/514 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/516 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/518 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/520 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/522 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/524 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/526 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/528 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/530 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/532 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/534 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/536 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/538 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/540 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/542 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/544 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/546 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/548 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/550 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/552 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/154 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/156 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/158 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/160 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/162 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/164 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/166 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/168 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/170 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/172 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/174 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/176 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/178 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/180 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/182 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/184 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/186 [00:00<?, ?it/s]

# %%
'''ringS1_chroma = ringS1.match( method='4d', solve=True,
    vary = [ xt.VaryList(['k2XF1arc', 'k2XD1arc'], step=1e-4 )],
    targets = [ xt.TargetSet(dqx=0, dqy=0, tol=1e-5 ) ]  )



ringS1_chroma.run_jacobian(10)'''
# Out:
# "ringS1_chroma = ringS1.match( method='4d', solve=True,\n    vary = [ xt.VaryList(['k2XF1arc', 'k2XD1arc'], step=1e-4 )],\n    targets = [ xt.TargetSet(dqx=0, dqy=0, tol=1e-5 ) ]  )\n\n\n\nringS1_chroma.run_jacobian(10)"

# %%
def ChromCorrect(ksf, ksd, MakePlot=False):
        
    opt_chrom = ringS2.match(
        solve=True,
        verbose=False,
        method='6d',
        vary=xt.VaryList([ksf, ksd], step=1e-4),
        targets=[
            # Global goals
            xt.Target(dqx=0, tol=1e-5),
            xt.Target(dqy=0, tol=1e-5),
            
            
        ])
    opt_chrom.target_status()
    opt_chrom.run_jacobian(10)
    opt_chrom.target_status()
    # Print the final matched strengths

    print(f"Matched kSF: {pdr.vars['k2XF2arc']._get_value():.6f}")
    print(f"Matched kSD: {pdr.vars['k2XD2arc']._get_value():.6f}")   
    #print(f"Matched kSF: {pdr.vars['k2XF2arc2']._get_value():.6f}")
    #print(f"Matched kSD: {pdr.vars['k2XD2arc2']._get_value():.6f}")   

ChromCorrect('k2XF2arc', 'k2XD2arc', MakePlot=False)
# Out:
# Matching: model call n. 1 penalty = 3.0428e+01
# Matching: model call n. 2 penalty = 3.0428e+01
# Matching: model call n. 3 penalty = 3.0428e+01
# Matching: model call n. 4 penalty = 3.0428e+01
# Matching: model call n. 5 penalty = 3.0428e+01
# Matching: model call n. 6 penalty = 1.5659e+01
# Matching: model call n. 7 penalty = 1.5659e+01
# Matching: model call n. 8 penalty = 1.5659e+01
# Matching: model call n. 9 penalty = 1.5659e+01
# Matching: model call n. 10 penalty = 1.5659e+01
# Matching: model call n. 11 penalty = 3.0845e-01
# Matching: model call n. 12 penalty = 3.0845e-01
# Matching: model call n. 13 penalty = 3.0847e-01
# Matching: model call n. 14 penalty = 3.0845e-01
# Matching: model call n. 15 penalty = 3.0845e-01
# Matching: model call n. 16 penalty = 5.1129e-02
# Matching: model call n. 17 penalty = 5.1129e-02
# Matching: model call n. 18 penalty = 5.1148e-02
# Matching: model call n. 19 penalty = 5.1131e-02
# Matching: model call n. 20 penalty = 5.1129e-02
# Matching: model call n. 21 penalty = 4.7705e-03
# Matching: model call n. 22 penalty = 4.7705e-03
# Matching: model call n. 23 penalty = 4.7898e-03
# Matching: model call n. 24 penalty = 4.7753e-03
# Matching: model call n. 25 penalty = 4.7705e-03
# Matching: model call n. 26 penalty = 8.1213e-05
# Matching: model call n. 27 penalty = 8.1213e-05
# Matching: model call n. 28 penalty = 1.0225e-04
# Matching: model call n. 29 penalty = 8.8291e-05
# Matching: model call n. 30 penalty = 8.1213e-05
# Matching: model call n. 31 penalty = 6.0393e-06
# Matching: model call n. 32 penalty = 6.0393e-06
# Target status:
# id state tag tol_met       residue   current_val target_val description
# 0  ON    dqx    True   6.03933e-06   6.03933e-06          0 'dqx', val=0, tol=1e-05, weight=1
# 1  ON    dqy    True  -2.84217e-10  -2.84217e-10          0 'dqy', val=0, tol=1e-05, weight=1
# Matching: model call n. 33 penalty = 6.0393e-06
# Matching: model call n. 34 penalty = 6.0393e-06
# Matching: model call n. 35 penalty = 6.0393e-06
# Target status:
# id state tag tol_met       residue   current_val target_val description
# 0  ON    dqx    True   6.03933e-06   6.03933e-06          0 'dqx', val=0, tol=1e-05, weight=1
# 1  ON    dqy    True  -2.84217e-10  -2.84217e-10          0 'dqy', val=0, tol=1e-05, weight=1
# Matched kSF: 181.930534
# Matched kSD: -264.768655

# %%
configs = {
    "arc1R": arc1R,
    "cell_arc": cell_arc,
    "cell_tr": cell_tr,
    "period": periodS2,
    "ring": ringS2,
    "pdr": pdr
}

for name, line in configs.items():
    filename = f"json_files/{name}_{n}.json"
    line.to_json(filename)
    print(f"Successfully saved: {filename}")
# Out:
# Successfully saved: json_files/arc1R_7.json
# Successfully saved: json_files/cell_arc_7.json
# Successfully saved: json_files/cell_tr_7.json
# Successfully saved: json_files/period_7.json
# Successfully saved: json_files/ring_7.json
# Successfully saved: json_files/pdr_7.json

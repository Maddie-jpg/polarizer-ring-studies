# %%
import sys
import os

# Adds the parent directory to the search path
parent_dir = os.path.abspath('..')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
import xtrack as xt
import numpy as np
import os
import matplotlib.pyplot  as plt
import matplotlib.patches as patches
import xpart as xp
import xobjects as xo
import math
import constants

# %%
#Pre-defined params
# %% create environment, parameters and first simple cells & structures
#reupload

#Design number
n=6

pdr = xt.Environment()
pdr.particle_ref = xt.Particles(kinetic_energy0=2.86e9, mass0 = xt.ELECTRON_MASS_EV)

E0 = constants.E0; VRF = constants.VRF # beam energy in eV and RF voltage (1 cavity) in V

pdr.vars({ 
'l_cell':   3.5000,
'l_bend':   0.4000,
'l_bendDS':   0.5500,
'dl_noben':   0.2500,
'l_quad':   0.3000,
'l_sext':   0.1000,
'l_drift':   '(l_cell - 2*l_bend - 2*l_quad-2*l_sext)/4.',
'dl_drift':  -0.1500,
'dl_trans':   0.0000,
'l_doub':   0.2500,
'l_tripl':   3.2500,
'l_trips':   0.4000,
'N_cells_S':   9.0000,
'hBarc':   0.1507,
'kQFarc':   2.8579,
'kQDarc':  -2.8333,
'kQFarcM':   2.7633,
'kQDarcM':  -3.1990,
'kQFDS':   2.8473,
'kQDDS':  -2.5869,
'kQFDoub':   3.7011,
'kQDDoub':  -2.3242,
'kQFtr':   4.1683,
'kQDtr':  -2.5106,

'kSF':  80.5236,
'kSD': -114.8259,
'kSF2':  0,
'kSD2': 0,})

pdr.vars({'N_cells_S': 8,'hBarc' : '6.283185307/(6*(2*N_cells_S*l_bend + l_bendDS))',
  'kQFarc': 2.9478, 'kQDarc':-2.9231,'kQFarcM': 2.8846, 'kQDarcM':-2.7567, 
  'kQFDS': 2.8042, 'kQDDS':-2.2858, 'kQFDoub': 3.9170, 'kQDDoub':-2.5190, 
  'kQFtr': 4.4429, 'kQDtr':-2.4723 } )

U0 = (0.88463e-31)*E0**4*(2.*np.pi)/(6*(2*pdr['N_cells_S']*pdr['l_bend'] + pdr['l_bendDS']) )

pdr.new('Bend', xt.Bend, length='l_bend', angle='hBarc*l_bend', k0_from_h=True, 
         edge_entry_angle='hBarc*l_bend/2', edge_exit_angle='hBarc*l_bend/2')
pdr.new('QFarc',  xt.Quadrupole, length='l_quad',    k1='kQFarc' )
pdr.new('QFarcH', xt.Quadrupole, length='l_quad/2.', k1='kQFarc' )
pdr.new('Drarc',  xt.Drift,      length='l_drift' )
pdr.new('DrarcS', xt.Drift,      length='l_drift + dl_drift' )
pdr.new('QDarc',  xt.Quadrupole, length='l_quad',    k1='kQDarc' )
pdr.new('QFarcM', xt.Quadrupole, length='l_quad',    k1='kQFarcM' )
pdr.new('QDarcM', xt.Quadrupole, length='l_quad',    k1='kQDarcM' )
pdr.new('BendDS', xt.Bend, length='l_bendDS', angle='hBarc*l_bendDS', k0_from_h=True, 
         edge_entry_angle='hBarc*l_bendDS/2', edge_exit_angle='hBarc*l_bendDS/2')
pdr.new('QFDS',   xt.Quadrupole, length='l_quad',    k1='kQFDS' )
pdr.new('QDDS',   xt.Quadrupole, length='l_quad',    k1='kQDDS' )
pdr.new('DrDSL',  xt.Drift,      length='2*l_drift + l_bend + dl_noben' )
pdr.new('DrTrans',xt.Drift,      length='l_drift + dl_trans' )
pdr.new('QFDoub', xt.Quadrupole, length='l_quad',    k1='kQFDoub' )
pdr.new('QDDoub', xt.Quadrupole, length='l_quad',    k1='kQDDoub' )
pdr.new('DrDoub', xt.Drift,      length='l_doub' )

pdr.new('QFtr',    xt.Quadrupole, length='l_quad',    k1='kQFtr' )
pdr.new('QFtrH',   xt.Quadrupole, length='l_quad/2.', k1='kQFtr' )
pdr.new('QDtr',    xt.Quadrupole, length='l_quad',    k1='kQDtr' )
pdr.new('QDtrH',   xt.Quadrupole, length='l_quad',    k1='kQDtr' )
pdr.new('DrTripl', xt.Drift,      length='l_tripl' )
pdr.new('DrTrips', xt.Drift,      length='l_trips' )

#Add any new variables and structures here


pdr.new('Drarc2', xt.Drift, length='(l_drift-l_sext)/2')
pdr.new('Drarc3', xt.Drift, length='((l_drift-l_sext)/2)+l_sext')

pdr.new('SFDS', xt.Sextupole, length='l_sext',k2='kSF')
pdr.new('SDDS', xt.Sextupole, length='l_sext',k2='kSD')

pdr.new('SFDS2', xt.Sextupole, length='l_sext',k2='kSF2')
pdr.new('SDDS2', xt.Sextupole, length='l_sext',k2='kSD2')
# Out:
# 'SDDS2'

# %%
# just an arc cell
cell_arcS = pdr.new_line( length='l_cell', 
    components =[ 
    pdr.new('QF_cell_arc',    'QFarc',at='0*l_drift + 0.5*l_quad + 0.0*l_bend'),
    pdr.new('SF_cell_arc','SFDS', at='l_quad+(l_drift-l_sext)/2+0.5*l_sext'),
    pdr.new('Bend1_cell_arc', 'Bend', at='1*l_drift + 1.0*l_quad + 0.5*l_bend'),
    pdr.new('QD_cell_arc',    'QDarc',at='2*l_drift + 1.5*l_quad + 1.0*l_bend'),
    pdr.new('SD_cell_arc','SDDS',at='2*l_drift+2*l_quad+l_bend+l_drift/2'),
    pdr.new('Bend2_cell_arc', 'Bend', at='3*l_drift + 2.0*l_quad + 1.5*l_bend'),
    ])
cell_arcS.survey().plot()
print(cell_arcS.get_length())
cell_arc = pdr.new_line( components = [ 
   pdr.new('QF_cell_arcH1',  'QFarcH' ), pdr.place( 'Drarc2' ),
   pdr.new('SF_cell_arc1', 'SFDS'), pdr.place('Drarc2'),
   pdr.new('Bend1_cell_arcH','Bend' ),   pdr.place( 'Drarc' ),
   pdr.new('QD_cell_arcH',   'QDarc' ),  pdr.place( 'Drarc2' ),
   pdr.new('SD_cell_arc1', 'SDDS'), pdr.place('Drarc2'),
   pdr.new('Bend2_cell_arcH','Bend' ),   pdr.place( 'Drarc' ),
   pdr.new('QF_cell_arcH2',  'QFarcH' ), 
   ])
cell_arc.survey().plot()
print(cell_arc.get_length())
# triplet starting with 
cell_tr = pdr.new_line(
    components = [
    pdr.new('QF_cell_trH1', 'QFtrH',    at='0*l_trips + 0.25*l_quad + 0.0*l_tripl'),
    pdr.new('QD_cell_tr1',  'QDtr',     at='1*l_trips + 1.00*l_quad + 0.0*l_tripl'),
    pdr.new('Mkr_cell_tr',   xt.Marker, at='1*l_trips + 1.50*l_quad + 0.5*l_tripl'),
    pdr.new('QD_cell_tr2',  'QDtr',     at='1*l_trips + 2.00*l_quad + 1.0*l_tripl'),
    pdr.new('QF_cell_trH2', 'QFtrH',    at='2*l_trips + 2.75*l_quad + 1.0*l_tripl')
    ])

print(cell_tr.get_length())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xplt/hooks.py:31: RuntimeWarning: Failed to register formatters with pint: No module named 'pint'
#   warnings.warn(f"Failed to register formatters with pint: {e}", RuntimeWarning)
# 3.5
# 3.3
# 4.95

# %%
#makesextant function
def makesextant ( name, fall ):
    comps = [ ]
    comps = comps + [pdr.new('Drarc0_'+name+str(0),'Drarc2'),pdr.new('SFA0_'+name+str(0),'SFDS2')]
    for ind in range(pdr['N_cells_S']-1):  # regular arc cells
     if ind % 2 == 0: 
       comps = comps + [ pdr.new('Drarc1_'+ name + str(ind+1), 'Drarc2'), pdr.new('Bend1_' + name + str(ind+1), 'Bend')]
       comps = comps + [ pdr.new('Drarc2_'+ name + str(ind+1), 'Drarc'), pdr.new('QDA_' + name + str(ind+1), 'QDarc')]
       comps = comps + [pdr.new('Drarc3_'+name+str(ind+1),'Drarc2'),pdr.new('SDA_'+name+str(ind+1),'SDDS')]
       comps = comps + [ pdr.new('Drarc4_'+ name + str(ind+1), 'Drarc2'), pdr.new('Bend2_' + name + str(ind+1), 'Bend')]
       comps = comps + [ pdr.new('Drarc5_'+ name + str(ind+1), 'Drarc'), pdr.new('QFA_' + name + str(ind), 'QFarc')]
       comps = comps + [pdr.new('Drarc6_'+name+str(ind+1),'Drarc2'),pdr.new('SFA_'+name+str(ind+1),'SFDS')]
    
     else:
       comps = comps + [ pdr.new('Drarc1.2_'+ name + str(ind+1), 'Drarc2'), pdr.new('Bend1.2_' + name + str(ind+1), 'Bend')]
       comps = comps + [ pdr.new('Drarc2.2_'+ name + str(ind+1), 'Drarc'), pdr.new('QDA.2_' + name + str(ind+1), 'QDarc')]
       comps = comps + [pdr.new('Drarc3.2_'+name+str(ind+1),'Drarc2'),pdr.new('SDA2_'+name+str(ind+1),'SDDS2')]
       comps = comps + [ pdr.new('Drarc4.2_'+ name + str(ind+1), 'Drarc2'), pdr.new('Bend2.2_' + name + str(ind+1), 'Bend')]
       comps = comps + [ pdr.new('Drarc5.2_'+ name + str(ind+1), 'Drarc'), pdr.new('QFA.2_' + name + str(ind), 'QFarc')]
       comps = comps + [pdr.new('Drarc6.2_'+name+str(ind+1),'Drarc2'),pdr.new('SFA2_'+name+str(ind+1),'SFDS2')]

    # Replace last QF and add last arc cell (matching quads) "by hand"
    comps[-3] = pdr.new('QFAM_' + name + str(pdr['N_cells_S']), 'QFarcM' )
    comps = comps + [pdr.new('DrarcS1_'+ name + str(ind+1), 'Drarc2'),pdr.new('Bend1_' + name + str(pdr['N_cells_S']), 'Bend')]
    comps = comps + [pdr.new('Drarc7_'+ name + str(ind+1), 'Drarc'), pdr.new('QDAM_' + name + str(pdr['N_cells_S']), 'QDarcM')]
    comps = comps + [pdr.new('Drarc75_'+name+str(ind+1),'Drarc2'),pdr.new('SDAM_'+name+str(ind+1),'SDDS2')]
    comps = comps + [pdr.new('Drarc8_'+ name + str(ind+1), 'Drarc2'), pdr.new('Bend2_' + name + str(pdr['N_cells_S']), 'Bend')]
    # Add dispersion suppressor
    comps = comps + [pdr.new('Drarc9_'+ name + str(ind+1), 'Drarc'), pdr.new('QFDS_' + name, 'QFDS') ]
    comps = comps + [pdr.new('DrDSL1_'+ name + str(ind+1), 'DrDSL'), pdr.new('QDDS_' + name, 'QDDS') ]
    comps = comps + [pdr.new('Drarc10_'+ name + str(ind+1), 'Drarc'), pdr.new('BendDS_' + name, 'BendDS')]
    # Add doublet matching 
    comps = comps + [pdr.new('DrTrans1_'+ name + str(ind+1), 'DrTrans'), pdr.new('QFDoub_' + name, 'QFDoub')]
    comps = comps + [pdr.new('DrDoub1_'+ name + str(ind+1), 'DrDoub'), pdr.new('QDDoub_' + name, 'QDDoub')]   
    comps = comps + [pdr.new('DrTripl1_'+ name + str(ind+1), 'DrTripl'), pdr.new('QDTrip_' + name + '1', 'QDtr')]  
    if fall == 'symm':
       comps = [ pdr.new('QFA_' + name + 'CH', 'QFarcH' ) ] + comps
       comps = comps + [ pdr.place('DrTrips'), pdr.new('QFTripC_' + name + '2H', 'QFtrH')]
    elif fall == 'right':
       comps = [ pdr.new('QFA_' + name + 'C', 'QFarc'  ) ] + comps + [ pdr.place('DrTrips') ]
    elif fall == 'left':
       comps = comps + [pdr.place('DrTrips'), pdr.new('QFTripC_' + name + '2', 'QFtr') ]
       comps = list( reversed(comps) )
    else:
       print( '=====> choice for sextant version incorrect <=====' )
       quit()
    return pdr.new_line( components = comps )

# %%
arc1R = makesextant( 'xR', 'symm' )
arc1R_sliced = arc1R.select()
arc1R_sliced.cut_at_s( np.linspace(.05, arc1R.get_length()-.05, int(arc1R.get_length()/.05-.5)) )
arc1R.insert( pdr.new('CtrS1_xR1', xt.Marker ), at='(l_tripl+l_quad)/2', from_='QDDoub_xR' )
arc1R.survey().plot()
# Out:
# Slicing line:   0%|          | 0/109 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/109 [00:00<?, ?it/s]

# %%
# %% Routine for several matchings in a row for 90 degrees arc cells and given tunes

# Matching of arc cell
cell_arc_opt = cell_arc.match( method='4d', solve=True, verbose=False,
    vary=[
        xt.VaryList(['kQFarc', 'kQDarc', 'kQFarcM'], step=1e-4),    ],
    targets=[
        xt.TargetSet(qx=0.25, qy=0.25, tol=1.0e-6, tag='end'), # just twice the same 
        xt.TargetSet(mux=0.25, muy=0.25, at=xt.END, tol=1.0e-6)]  )

# Triplet cell to chosen betatron functions
cell_tr_opt = cell_tr.match( method='4d', solve=True,
    vary=[ # use individual Vary commands instead of List for arc cell
        xt.Vary('kQFtr', step=1e-4 ),
        xt.Vary('kQDtr', step=1e-4),    ],
    targets=[
        xt.TargetSet(betx=2.50, bety=2.50, at='Mkr_cell_tr', tol=1.0e-6, tag='betas')] )

def matchingWP( qx, qy, MakePlot=False ):
    cell_arc_opt.run_jacobian(10)
    cell_arc_tw = cell_arc.twiss( method='4d' )
    arc1R_opttune = arc1R.match( method='4d', solve=True, verbose=False,
                 betx=cell_arc_tw.betx[0], alfx=cell_arc_tw.alfx[0],
                 bety=cell_arc_tw.bety[0], alfy=cell_arc_tw.alfy[0],
                 dx=cell_arc_tw.dx[0],     dpx=cell_arc_tw.dpx[0],
            vary=[ xt.VaryList(['kQFarcM', 'kQDarcM'], step=1e-4),
                   xt.VaryList(['kQFDS', 'kQDDS'], step=1e-4),
                   xt.VaryList(['kQFDoub', 'kQDDoub'], step=1e-4),
                   xt.VaryList(['kQFtr', 'kQDtr'], step=1e-4), ],
            targets=[ xt.TargetSet(dx=0, dpx=0, at=xt.END, tol=1.0e-9),
                      xt.TargetSet(mux=qx/6, muy=qy/6, at=xt.END, 
                                   tol=1.0e-9, weight=.1, tag='phase'),
                      xt.TargetSet(alfx=0, alfy=0, at=xt.END, tol=1.0e-9),
                      xt.TargetSet(alfx=0, alfy=0, at='CtrS1_xR1', 
                                   tol=1.0e-9, weight=10.) ])
    arc1R_opttune.run_jacobian(50)
    if MakePlot:
       arc1R.twiss( method='4d',
                    betx=cell_arc_tw.betx[0], alfx=cell_arc_tw.alfx[0],
                    bety=cell_arc_tw.bety[0], alfy=cell_arc_tw.alfy[0],
                    dx=cell_arc_tw.dx[0],     dpx=cell_arc_tw.dpx[0],).plot()

        
# Matching sequence for sextant with beta at center of straights fixed
def matchingBeta( betxS, betyS, MakePlot=False ): #, **kwargs ):
    cell_arc_opt.run_jacobian(10)
    cell_arc_tw = cell_arc.twiss( method='4d' )
    cell_tr_opt.targets[0].value, cell_tr_opt.targets[1].value = betxS, betyS
    cell_tr_opt.run_jacobian(10)
    cell_tr_tw = cell_tr.twiss( method='4d' )
    arc1R_opt = arc1R.match( method='4d', solve=True,
                 betx=cell_arc_tw.betx[0], alfx=cell_arc_tw.alfx[0],
                 bety=cell_arc_tw.bety[0], alfy=cell_arc_tw.alfy[0],
                 dx=cell_arc_tw.dx[0],     dpx=cell_arc_tw.dpx[0],
            vary=[ xt.VaryList(['kQFarcM', 'kQDarcM'], step=1e-4),
                   xt.VaryList(['kQFDS', 'kQDDS'], step=1e-4),
                   xt.VaryList(['kQFDoub', 'kQDDoub'], step=1e-4) ],
            targets=[ xt.TargetSet(dx=0, dpx=0, at=xt.END, tol=1.0e-9),
                      xt.TargetSet(alfx=0, alfy=0, at=xt.END, tol=1.0e-9),
                      xt.TargetSet(betx=cell_tr_tw.betx[0], bety=cell_tr_tw.bety[0],
                                   at=xt.END, tol=1.0e-9) ])
    arc1R_opt.run_jacobian(10)
    if MakePlot:
       arc1R.twiss( method='4d',
                    betx=cell_arc_tw.betx[0], alfx=cell_arc_tw.alfx[0],
                    bety=cell_arc_tw.bety[0], alfy=cell_arc_tw.alfy[0],
                    dx=cell_arc_tw.dx[0],     dpx=cell_arc_tw.dpx[0],).plot() 
       

matchingWP(*constants.WP)

cell_tr_tw = cell_tr.twiss(method='4d')
mid_idx = len(cell_tr_tw.betx) // 2
betxS = cell_tr_tw.betx[mid_idx]
betyS = cell_tr_tw.bety[mid_idx]
matchingBeta( betxS, betyS, MakePlot=False )
# Out:
# Matching: model call n. 1 penalty = 1.9473e-01
# Matching: model call n. 2 penalty = 1.9473e-01
# Matching: model call n. 3 penalty = 1.9462e-01
# Matching: model call n. 4 penalty = 1.9483e-01
# Matching: model call n. 5 penalty = 1.9473e-01
# Matching: model call n. 6 penalty = 1.9473e-01
# Matching: model call n. 7 penalty = 2.9617e-03
# Matching: model call n. 8 penalty = 2.9617e-03
# Matching: model call n. 9 penalty = 3.0696e-03
# Matching: model call n. 10 penalty = 2.8630e-03
# Matching: model call n. 11 penalty = 2.9617e-03
# Matching: model call n. 12 penalty = 2.9617e-03
# Matching: model call n. 13 penalty = 6.9814e-07
#
# Matching: model call n. 1 penalty = 9.1280e-01
# Optimize - start penalty: 0.9128
# Matching: model call n. 2 penalty = 9.1280e-01
# Matching: model call n. 3 penalty = 9.1306e-01
# Matching: model call n. 4 penalty = 9.1306e-01
# Matching: model call n. 5 penalty = 9.1280e-01
# Matching: model call n. 6 penalty = 1.8589e-01
# Matching: model call n. 7 penalty = 1.8589e-01
# Matching: model call n. 8 penalty = 1.8550e-01
# Matching: model call n. 9 penalty = 1.8557e-01
# Matching: model call n. 10 penalty = 1.8589e-01
# Matching: model call n. 11 penalty = 6.9956e-03
# Matching: model call n. 12 penalty = 6.9956e-03
# Matching: model call n. 13 penalty = 6.6371e-03
# Matching: model call n. 14 penalty = 6.6948e-03
# Matching: model call n. 15 penalty = 6.9956e-03
# Matching: model call n. 16 penalty = 1.0172e-05
# Matching: model call n. 17 penalty = 1.0172e-05
# Matching: model call n. 18 penalty = 3.5314e-04
# Matching: model call n. 19 penalty = 3.6646e-04
# Matching: model call n. 20 penalty = 1.0172e-05
# Matching: model call n. 21 penalty = 8.9164e-10
# Optimize - end penalty:  8.91639e-10
# Matching: model call n. 14 penalty = 6.9814e-07
# Matching: model call n. 15 penalty = 6.9814e-07
# Matching: model call n. 1 penalty = 5.3135e+00
# Matching: model call n. 2 penalty = 5.3135e+00
# Matching: model call n. 3 penalty = 5.3151e+00
# Matching: model call n. 4 penalty = 5.3129e+00
# Matching: model call n. 5 penalty = 5.3117e+00
# Matching: model call n. 6 penalty = 5.3139e+00
# Matching: model call n. 7 penalty = 5.3155e+00
# Matching: model call n. 8 penalty = 5.3148e+00
# Matching: model call n. 9 penalty = 5.3121e+00
# Matching: model call n. 10 penalty = 5.3120e+00
# Matching: model call n. 11 penalty = 5.3135e+00
# Matching: model call n. 12 penalty = 3.7329e+02
# Matching: model call n. 13 penalty = 2.6519e+01
# Matching: model call n. 14 penalty = 3.8942e+00
# Matching: model call n. 15 penalty = 3.8942e+00
# Matching: model call n. 16 penalty = 3.8938e+00
# Matching: model call n. 17 penalty = 3.8935e+00
# Matching: model call n. 18 penalty = 3.8936e+00
# Matching: model call n. 19 penalty = 3.8927e+00
# Matching: model call n. 20 penalty = 3.8933e+00
# Matching: model call n. 21 penalty = 3.8935e+00
# Matching: model call n. 22 penalty = 3.8956e+00
# Matching: model call n. 23 penalty = 3.8947e+00
# Matching: model call n. 24 penalty = 3.8942e+00
# Matching: model call n. 25 penalty = 3.4965e+03
# Matching: model call n. 26 penalty = 4.5383e+02
# Matching: model call n. 27 penalty = 6.1169e+01
# Matching: model call n. 28 penalty = 1.1731e+01
# Matching: model call n. 29 penalty = 4.8048e+00
# Matching: model call n. 30 penalty = 4.8048e+00
# Matching: model call n. 31 penalty = 4.8047e+00
# Matching: model call n. 32 penalty = 4.8041e+00
# Matching: model call n. 33 penalty = 4.8035e+00
# Matching: model call n. 34 penalty = 4.7984e+00
# Matching: model call n. 35 penalty = 4.8032e+00
# Matching: model call n. 36 penalty = 4.8031e+00
# Matching: model call n. 37 penalty = 4.8057e+00
# Matching: model call n. 38 penalty = 4.8044e+00
# Matching: model call n. 39 penalty = 4.8048e+00
# Matching: model call n. 40 penalty = nan
# Matching: model call n. 41 penalty = 8.4221e+15
# Matching: model call n. 42 penalty = 1.1903e+17
# Matching: model call n. 43 penalty = 1.4533e+15
# Matching: model call n. 44 penalty = 1.1165e+13
# Matching: model call n. 45 penalty = 9.1978e+08
# Matching: model call n. 46 penalty = 1.9663e+05
# Matching: model call n. 47 penalty = 1.7135e+02
# Matching: model call n. 48 penalty = 1.0598e+02
# Matching: model call n. 49 penalty = 2.0524e+01
# Matching: model call n. 50 penalty = 2.0524e+01
# Matching: model call n. 51 penalty = 2.0525e+01
# Matching: model call n. 52 penalty = 2.0523e+01
# Matching: model call n. 53 penalty = 2.0523e+01
# Matching: model call n. 54 penalty = 2.0527e+01
# Matching: model call n. 55 penalty = 2.0526e+01
# Matching: model call n. 56 penalty = 2.0527e+01
# Matching: model call n. 57 penalty = 2.0524e+01
# Matching: model call n. 58 penalty = 2.0525e+01
# Matching: model call n. 59 penalty = 2.0524e+01
# Matching: model call n. 60 penalty = 3.5966e+01
# Matching: model call n. 61 penalty = 2.1582e+00
# Matching: model call n. 62 penalty = 2.1582e+00
# Matching: model call n. 63 penalty = 2.1582e+00
# Matching: model call n. 64 penalty = 2.1579e+00
# Matching: model call n. 65 penalty = 2.1580e+00
# Matching: model call n. 66 penalty = 2.1582e+00
# Matching: model call n. 67 penalty = 2.1575e+00
# Matching: model call n. 68 penalty = 2.1576e+00
# Matching: model call n. 69 penalty = 2.1593e+00
# Matching: model call n. 70 penalty = 2.1591e+00
# Matching: model call n. 71 penalty = 2.1582e+00
# Matching: model call n. 72 penalty = 8.2033e-01
# Matching: model call n. 73 penalty = 8.2033e-01
# Matching: model call n. 74 penalty = 8.2011e-01
# Matching: model call n. 75 penalty = 8.1960e-01
# Matching: model call n. 76 penalty = 8.2051e-01
# Matching: model call n. 77 penalty = 8.2152e-01
# Matching: model call n. 78 penalty = 8.1982e-01
# Matching: model call n. 79 penalty = 8.1983e-01
# Matching: model call n. 80 penalty = 8.2109e-01
# Matching: model call n. 81 penalty = 8.1958e-01
# Matching: model call n. 82 penalty = 8.2033e-01
# Matching: model call n. 83 penalty = 1.9903e-02
# Matching: model call n. 84 penalty = 1.9903e-02
# Matching: model call n. 85 penalty = 1.8718e-02
# Matching: model call n. 86 penalty = 2.1300e-02
# Matching: model call n. 87 penalty = 2.1235e-02
# Matching: model call n. 88 penalty = 1.9882e-02
# Matching: model call n. 89 penalty = 1.9081e-02
# Matching: model call n. 90 penalty = 2.0197e-02
# Matching: model call n. 91 penalty = 2.1815e-02
# Matching: model call n. 92 penalty = 2.1543e-02
# Matching: model call n. 93 penalty = 1.9903e-02
# Matching: model call n. 94 penalty = 1.2588e-05
# Matching: model call n. 95 penalty = 1.2588e-05
# Matching: model call n. 96 penalty = 1.8432e-03
# Matching: model call n. 97 penalty = 2.1932e-03
# Matching: model call n. 98 penalty = 2.2183e-03
# Matching: model call n. 99 penalty = 8.3245e-04
# Matching: model call n. 100 penalty = 2.0752e-03
# Matching: model call n. 101 penalty = 1.9085e-03
# Matching: model call n. 102 penalty = 2.5102e-03
# Matching: model call n. 103 penalty = 1.8061e-03
# Matching: model call n. 104 penalty = 1.2588e-05
# Matching: model call n. 105 penalty = 1.4252e-09
# Matching: model call n. 106 penalty = 1.4252e-09
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xtrack/particles/particles.py:1770: RuntimeWarning: invalid value encountered in sqrt
#   out = sqrt((1 + self.delta) ** 2 - self.kin_px ** 2 - self.kin_py ** 2)
# Matching: model call n. 107 penalty = 1.4252e-09
# Matching: model call n. 16 penalty = 6.9814e-07
# Matching: model call n. 17 penalty = 6.9814e-07
# Matching: model call n. 22 penalty = 0.0000e+00
# Optimize - start penalty: 0
# Matching: model call n. 23 penalty = 0.0000e+00
# Optimize - end penalty:     0
#
# Matching: model call n. 1 penalty = 1.4108e-09
# Optimize - start penalty: 1.411e-09
# Matching: model call n. 2 penalty = 1.4108e-09
# Optimize - end penalty:  1.41085e-09
#
# Matching: model call n. 3 penalty = 1.4108e-09
# Optimize - start penalty: 1.411e-09
# Matching: model call n. 4 penalty = 1.4108e-09
# Optimize - end penalty:  1.41085e-09

# %%
# One period from center of arc to center of arc
plt.rcParams['figure.figsize'] = [7,7]
period = makesextant( 'PR', 'symm') + ( -makesextant( 'PL', 'symm') )
period.survey().plot()
period_sliced = period.select()
period_sliced.cut_at_s( np.linspace(.05, period.get_length()-.05, int(period.get_length()/.05-.5)) )
# Out:
# Slicing line:   0%|          | 0/218 [00:00<?, ?it/s]

# %%
ring  = makesextant( '1R', 'right') + makesextant( '2L', 'left') + makesextant( '2R', 'right') + makesextant( '3L', 'left') + makesextant( '3R', 'right') + makesextant( '1L', 'left')

fRev = 1./(ring.twiss(method='4d').T_rev0)
fRF  = fRev*round(4.e8/fRev)  # at integer harmonics and close to 400 MHz
pdr.new('RFCav',  xt.Cavity, length=1.5, frequency=fRF, voltage=VRF, 
        lag=(180/np.pi)*(np.pi - np.arcsin(U0/VRF)) - 1.8 ) 
ring.insert( pdr.new('RFCav_1', 'RFCav'), at='(l_tripl+l_quad)/2', from_='QDDoub_1R' )
ring.configure_radiation(model='mean')
ring.configure_bend_model(edge='full')
# Out:
# Slicing line:   0%|          | 0/648 [00:00<?, ?it/s]

# %%
def ChromCorrect(ksf, ksd,ksf2,ksd2, MakePlot=False):
        
    opt_chrom = ring.match(
        solve=True,
        verbose=False,
        method='6d',
        vary=xt.VaryList([ksf, ksd, ksf2,ksd2], step=1e-3),
        targets=[
            # Global goals
            xt.Target(dqx=0, tol=1e-4),
            xt.Target(dqy=0, tol=1e-4),
            
            
        ])
    opt_chrom.target_status()
    opt_chrom.run_jacobian(n_steps=100)
    opt_chrom.target_status()
    # Print the final matched strengths

    print(f"Matched kSF: {pdr.vars[f'{ksf}']._get_value():.6f}")
    print(f"Matched kSD: {pdr.vars[f'{ksd}']._get_value():.6f}")   
    print(f"Matched kSF: {pdr.vars[f'{ksf2}']._get_value():.6f}")
    print(f"Matched kSD: {pdr.vars[f'{ksd2}']._get_value():.6f}")  

ChromCorrect('kSF', 'kSD','kSF2','kSD2', MakePlot=False)
# Out:
# Matching: model call n. 1 penalty = 2.0307e+01
# Matching: model call n. 2 penalty = 2.0307e+01
# Matching: model call n. 3 penalty = 2.0307e+01
# Matching: model call n. 4 penalty = 2.0307e+01
# Matching: model call n. 5 penalty = 2.0307e+01
# Matching: model call n. 6 penalty = 2.0307e+01
# Matching: model call n. 7 penalty = 2.0307e+01
# Matching: model call n. 8 penalty = 2.9560e-01
# Matching: model call n. 9 penalty = 2.9560e-01
# Matching: model call n. 10 penalty = 2.9542e-01
# Matching: model call n. 11 penalty = 2.9556e-01
# Matching: model call n. 12 penalty = 2.9542e-01
# Matching: model call n. 13 penalty = 2.9555e-01
# Matching: model call n. 14 penalty = 2.9560e-01
# Matching: model call n. 15 penalty = 1.3430e-03
# Matching: model call n. 16 penalty = 1.3430e-03
# Matching: model call n. 17 penalty = 1.5234e-03
# Matching: model call n. 18 penalty = 1.3918e-03
# Matching: model call n. 19 penalty = 1.5230e-03
# Matching: model call n. 20 penalty = 1.3942e-03
# Matching: model call n. 21 penalty = 1.3430e-03
# Matching: model call n. 22 penalty = 4.7528e-06
# Matching: model call n. 23 penalty = 4.7528e-06
# Target status:
# id state tag tol_met       residue   current_val target_val description
# 0  ON    dqx    True  -4.75281e-06  -4.75281e-06          0 'dqx', val=0, tol=0.0001, weight=1
# 1  ON    dqy    True   -1.7412e-09   -1.7412e-09          0 'dqy', val=0, tol=0.0001, weight=1
# Matching: model call n. 24 penalty = 4.7528e-06
# Matching: model call n. 25 penalty = 4.7528e-06
# Matching: model call n. 26 penalty = 4.7528e-06
# Target status:
# id state tag tol_met       residue   current_val target_val description
# 0  ON    dqx    True  -4.75281e-06  -4.75281e-06          0 'dqx', val=0, tol=0.0001, weight=1
# 1  ON    dqy    True   -1.7412e-09   -1.7412e-09          0 'dqy', val=0, tol=0.0001, weight=1
# Matched kSF: 141.482681
# Matched kSD: -218.459602
# Matched kSF: 60.621682
# Matched kSD: -98.813423

# %%
configs = {
    "arc1R": arc1R,
    "cell_arc": cell_arc,
    "cell_tr": cell_tr,
    "period": period,
    "ring": ring,
    "pdr": pdr
}

for name, line in configs.items():
    filename = f"json_files/{name}_{n}.json"
    line.to_json(filename)
    print(f"Successfully saved: {filename}")
# Out:
# Successfully saved: json_files/arc1R_6.json
# Successfully saved: json_files/cell_arc_6.json
# Successfully saved: json_files/cell_tr_6.json
# Successfully saved: json_files/period_6.json
# Successfully saved: json_files/ring_6.json
# Successfully saved: json_files/pdr_6.json
